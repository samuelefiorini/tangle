# %%
import pandas as pd

# %% [markdown]
# # BTOS-4D definition
# Create the modified version of `BTOS` symbols. In this modified version, there are less symbols and some of them are specific to the problem. At first we load the standard ITEM - BTOS association.

# %%
imap = pd.read_csv('../mbspbs10pc/data/imap_derived.csv', header=0, index_col=0)
imap.head(10)
# Out:
#    ITEM  BTOS (Heirarchy order) BTOS
# 0     1                     101    A
# 1     2                     101    A
# 2     3                     101    A
# 3     4                     101    A
# 4     5                     103    B
# 5     6                     103    B
# 6     7                     103    B
# 7     8                     103    B
# 8     9                     103    B
# 9    10                     103    B

# %%
# imap[imap['BTOS'] == 'C']

# %% [markdown]
# Load the modified `btos_details.csv` file.

# %%
columns = ['BTOS (Heirarchy order)', 'BTOS NAME', 'BTOS-4D NAME', 'BTOS-4D', 'BTOS']
btos_details = pd.read_csv('../mbspbs10pc/data/btos_details.csv', header=0, usecols=columns)
btos_details.head(16)
# Out:
#     BTOS (Heirarchy order) BTOS  \
# 0                    101.0    A
# 1                    102.0    M
# 2                    103.0    B
# 3                    110.0    O
# 4                    150.0    P
# 5                    200.0    C
# 6                    300.0    D
# 7                    400.0    E
# 8                    501.0    N
# 9                    502.0    F
# 10                   600.0    G
# 11                   700.0    H
# 12                   800.0    I
# 13                   900.0    J
# 14                  1000.0    K
# 15                  1100.0    L
#
#                                            BTOS NAME            BTOS-4D NAME  \
# 0                  Non-referred attendances GP/VR GP                      GP
# 1   Non-referred attendances - Enhanced Primary Care                      GP
# 2                   Non-referred attendances - Other                      GP
# 3    Non-referred attendances - Practice Nurse Items                      GP
# 4                                Other Allied Health     Other Allied Health
# 5                             Specialist attendances  Specialist attendances
# 6                                         Obstetrics              Obstetrics
# 7                                       Anaesthetics                 Surgery
# 8                         Pathology Collection Items               Pathology
# 9                                    Pathology Tests               Pathology
# 10                                Diagnostic Imaging              Diagnostic
# 11                                        Operations                 Surgery
# 12                          Assistance at Operations                 Surgery
# 13                                         Optometry               Optometry
# 14     Radiotherapy and Therapeutic Nuclear Medicine             Therapeutic
# 15                                Other MBS services             Therapeutic
#
#    BTOS-4D
# 0        G
# 1        G
# 2        G
# 3        G
# 4        L
# 5        E
# 6        B
# 7        S
# 8        P
# 9        P
# 10       I
# 11       S
# 12       S
# 13       O
# 14       T
# 15       T

# %% [markdown]
# Init the `'BTOS-4D'` column of `imap` using the corresponding symbols in `btos_details.csv`.

# %%
columns = ['ITEM', 'BTOS (Heirarchy order)', 'BTOS-4D']
btos4d = pd.merge(imap, btos_details, how='left', on='BTOS (Heirarchy order)')[columns]
btos4d.head(10)
# Out:
#    ITEM BTOS (Heirarchy order) BTOS-4D
# 0     1                    101       G
# 1     2                    101       G
# 2     3                    101       G
# 3     4                    101       G
# 4     5                    103       G
# 5     6                    103       G
# 6     7                    103       G
# 7     8                    103       G
# 8     9                    103       G
# 9    10                    103       G

# %%
# btos4d[btos4d['BTOS-4D'] == 'E']

# %% [markdown]
# - Now create the special diabetes-related simbols. Let's start with `'D'`.

# %%
# Assign to the following MBS ITEMs a new BTO -> D
annual_cycle_care = [2620, 2622, 2624, 2631, 2633, 2635, 2517, 2518, 2521, 2522, 2525, 2526]
eye_exam = [10915]
allied_health_services_diabetes = [81100, 81105, 81110, 81115, 81120, 81125]
to_D = annual_cycle_care + eye_exam + allied_health_services_diabetes
print(to_D)
# Out:
# [2620, 2622, 2624, 2631, 2633, 2635, 2517, 2518, 2521, 2522, 2525, 2526, 10915, 81100, 81105, 81110, 81115, 81120, 81125]

# %%
# Before
btos4d[btos4d['ITEM'].isin(to_D)]
# Out:
#         ITEM BTOS (Heirarchy order) BTOS-4D
# 2007    2517                    101       G
# 2008    2518                    101       G
# 2010    2521                    101       G
# 2011    2522                    101       G
# 2013    2525                    101       G
# 2014    2526                    101       G
# 2068    2620                    103       G
# 2070    2622                    103       G
# 2071    2624                    103       G
# 2075    2631                    103       G
# 2076    2633                    103       G
# 2078    2635                    103       G
# 4630   10915                    900       O
# 12097  81100                    150       L
# 12098  81105                    150       L
# 12099  81110                    150       L
# 12100  81115                    150       L
# 12101  81120                    150       L
# 12102  81125                    150       L

# %%
# After
btos4d.at[btos4d['ITEM'].isin(to_D), 'BTOS-4D'] = 'D'
btos4d[btos4d['ITEM'].isin(to_D)]
# Out:
#         ITEM BTOS (Heirarchy order) BTOS-4D
# 2007    2517                    101       D
# 2008    2518                    101       D
# 2010    2521                    101       D
# 2011    2522                    101       D
# 2013    2525                    101       D
# 2014    2526                    101       D
# 2068    2620                    103       D
# 2070    2622                    103       D
# 2071    2624                    103       D
# 2075    2631                    103       D
# 2076    2633                    103       D
# 2078    2635                    103       D
# 4630   10915                    900       D
# 12097  81100                    150       D
# 12098  81105                    150       D
# 12099  81110                    150       D
# 12100  81115                    150       D
# 12101  81120                    150       D
# 12102  81125                    150       D

# %% [markdown]
# - Now let's do that for the Hb1c test, which goes to `'H'`.

# %%
# Hb1c test -> H
hb1c = [66841]
to_H = hb1c
print(to_H)
# Out:
# [66841]

# %%
# Before
btos4d[btos4d['ITEM'].isin(to_H)]
# Out:
#         ITEM BTOS (Heirarchy order) BTOS-4D
# 11449  66841                    502       P

# %%
# After
btos4d.at[btos4d['ITEM'].isin(to_H), 'BTOS-4D'] = 'H'
btos4d[btos4d['ITEM'].isin(to_H)]
# Out:
#         ITEM BTOS (Heirarchy order) BTOS-4D
# 11449  66841                    502       H

# %% [markdown]
# - Finally, let's do that for the symbol `'R'`.

# %%
# Health assessment for people 40-49 years at risk
health_assessment_risk = [701, 703, 705, 707]
to_R = health_assessment_risk
print(to_R)
# Out:
# [701, 703, 705, 707]

# %%
# Before
btos4d[btos4d['ITEM'].isin(to_R)]
# Out:
#      ITEM BTOS (Heirarchy order) BTOS-4D
# 408   701                    102       G
# 410   703                    102       G
# 412   705                    102       G
# 414   707                    102       G

# %%
# After
btos4d.at[btos4d['ITEM'].isin(to_R), 'BTOS-4D'] = 'R'
btos4d[btos4d['ITEM'].isin(to_R)]
# Out:
#      ITEM BTOS (Heirarchy order) BTOS-4D
# 408   701                    102       R
# 410   703                    102       R
# 412   705                    102       R
# 414   707                    102       R

# %% [markdown]
# The new vocabulary is done. Let's print out the list of new symbols.

# %%
symbols = set(btos4d['BTOS-4D'].values)
print('There are {} unique symbols:'.format(len(symbols)))
for s in symbols:
    print('- {}'.format(s))
# Out:
# There are 12 unique symbols:
# - B
# - E
# - D
# - G
# - I
# - H
# - L
# - O
# - P
# - S
# - R
# - T

# %% [markdown]
# Let's save the new vocabulary as `data/btos4d.csv`.

# %%
btos4d.to_csv('../mbspbs10pc/data/btos4d.csv')

# %%
btos4d.head()
# Out:
#    ITEM BTOS (Heirarchy order) BTOS-4D
# 0     1                    101       G
# 1     2                    101       G
# 2     3                    101       G
# 3     4                    101       G
# 4     5                    103       G
